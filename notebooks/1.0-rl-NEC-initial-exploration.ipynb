# %% [markdown]
# # EU National Emission Ceilings (NEC) Directive Inventory
#
# Data from 1990 to 2021
#
# Source : https://www.eea.europa.eu/data-and-maps/data/ds_resolveuid/2BFB06C9-AB28-41EC-9808-576E32A36410
#
# By : Robin Lotode
#
# Setup : Download CSV file from Source link, add it in project/data/raw

# %% [markdown]
# Documentation : (from source file NEC_NFR19_2023_2023.xlsx)
#
# National Emission Ceilings (NEC) Directive Inventory - NFR19 sector classification - feature catalogue
#
# |Name |	Definition |
# |---|---|
# |Emissions  (float(8)) |	Emission value. |
# |Country_code  (varchar(4)) |	International Country Code. Note: ISO 3166-1-Alpha-2 code elements |
# |Country  (varchar(53)) |	Country name. |
# |Pollutant_name  (varchar(20)) |	Short name of pollutant. Note: NH3, NMVOC, NOX, SO2 |
# |Format_name  (varchar(100)) |	Name of guideline. Note: NFR19 sector classification |
# |Sector_code  (varchar(15)) |	Sector code. Note: NFR19 sector classification |
# |Parent_sector_code  (varchar(15)) |	Parent sector code. Note: NFR09 sector classification |
# |Sector_name  (varchar(75)) |	Sector name. Note: NFR19 sector classification |
# |Year  (varchar(4)) |	Annual data. Note: 1990-2021 |
# |Unit  (varchar(40)) |	Emission unit. Note: Kilotonne (1000 tonnes) |
# |Notation  (varchar(40)) |	Notation key. |

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
import plotly
pd.options.plotting.backend = "plotly"
pd.set_option('expand_frame_repr', False)

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Opening the dataset

# %%
df = pd.read_csv("../data/raw/NEC_NFR19_2023_23.06.27.csv", delimiter="\t")
df = df.rename(str.lower, axis='columns')
df.dtypes
df.shape
df.head()
# Out:
# country_code           object
# country                object
# pollutant_name         object
# format_name            object
# sector_code            object
# parent_sector_code     object
# sector_name            object
# year                    int64
# emissions             float64
# unit                   object
# notations              object
# dtype: object
# (4430070, 11)
#   country_code  country            pollutant_name                      format_name sector_code parent_sector_code                                        sector_name  year  emissions              unit notations
# 0           EE  Estonia                       SO2  NEC NFR14 sector classification      1A4bii     NATIONAL TOTAL      Residential: Household and gardening (mobile)  2002   0.005180  Gg (1000 tonnes)       NaN
# 1           MT    Malta  Indeno (1,2,3-cd) Pyrene  NEC NFR14 sector classification        1A5a     NATIONAL TOTAL              Other stationary (including military)  1997        NaN                 t        NO
# 2           RO  Romania                        BC  NEC NFR14 sector classification        2D3b     NATIONAL TOTAL                           Road paving with asphalt  2021   0.008868  Gg (1000 tonnes)       NaN
# 3           FR   France                     PM2.5  NEC NFR14 sector classification      1A4bii     NATIONAL TOTAL      Residential: Household and gardening (mobile)  1982        NaN  Gg (1000 tonnes)        NR
# 4           DE  Germany                        BC  NEC NFR14 sector classification      1A4cii     NATIONAL TOTAL  Agriculture/Forestry/Fishing: Off-road vehicle...  2005   3.093850  Gg (1000 tonnes)       NaN

# %% [markdown]
# ## Checking values

# %% [markdown]
# ### Missing values

# %%
print("Missing values :")
df.isnull().sum()

df_dict = {}
for col in df.columns:
    if col != "emissions":
        print(f'{col} unique values : {len(list(df[col].unique()))}')
        df_dict[col] = df[col].value_counts()
# Out:
# Missing values :
# country_code                0
# country                     0
# pollutant_name              0
# format_name                 0
# sector_code                 0
# parent_sector_code     262565
# sector_name                 0
# year                        0
# emissions             3169885
# unit                        0
# notations             2887851
# dtype: int64
# country_code unique values : 28
# country unique values : 28
# pollutant_name unique values : 31
# format_name unique values : 1
# sector_code unique values : 139
# parent_sector_code unique values : 2
# sector_name unique values : 136
# year unique values : 42
# unit unique values : 5
# notations unique values : 12

# %% [markdown]
# The column "format_name" has one single unique value, so we can ignore it

# %%
df = df.drop("format_name")

# %%
for key, value in df_dict.items():
    if key in ["unit", "notations"]:
        print(key, ":", value, "\n")
# Out:
# unit : unit
# t                   1729350
# Gg (1000 tonnes)    1712520
# TJNCV                617625
# kg                   247050
# g I-TEQ              123525
# Name: count, dtype: int64
#
# notations : notations
# NO    802444
# NE    340031
# NR    200782
# IE    197660
# ??       563
# C        451
# N.        98
# N/        64
# N?        64
# ?.        61
# Na         1
# Name: count, dtype: int64

# %% [markdown]
# Notation keys appear when the Emissions value is missing, explaining the reason why.
#
# Notation keys : (from https://unfccc.int/files/national_reports/annex_i_ghg_inventories/reporting_requirements/application/pdf/crf_reporter_user_manual.pdf#page=74)
# |Key | Meaning |
# |---|---|
# |NO | not occurring |
# |NE | not estimated |
# |NA | not applicable |
# |IE | included elsewhere |
# |C | Confidential |
#
# Some notation key values aren't in the expected values [NO, NE, NR, IE, C] :

# %%
df[(df["notations"].notnull()) & (~df["notations"].isin(["NO", "NE", "NR", "IE", "C"]))]
# Out:
#         country_code    country pollutant_name                      format_name sector_code parent_sector_code                                        sector_name  year  emissions              unit notations
# 7352              GR     Greece          PM2.5  NEC NFR14 sector classification      1B2aiv     NATIONAL TOTAL         Fugitive emissions oil: Refining / storage  2017        NaN  Gg (1000 tonnes)        ??
# 15048             GR     Greece            NH3  NEC NFR14 sector classification       1A4ai     NATIONAL TOTAL               Commercial/institutional: Stationary  2005        NaN  Gg (1000 tonnes)        ??
# 22490             GR     Greece            NOx  NEC NFR14 sector classification      1B2aiv     NATIONAL TOTAL         Fugitive emissions oil: Refining / storage  2012        NaN  Gg (1000 tonnes)        ??
# 27226             LT  Lithuania            NOx  NEC NFR14 sector classification         3Dc     NATIONAL TOTAL  Farm-level agricultural operations including s...  2001        NaN  Gg (1000 tonnes)        ??
# 32754             GR     Greece             Se  NEC NFR14 sector classification   1A3ai(ii)                NaN              International aviation cruise (civil)  2012        NaN                 t        N.
# ...              ...        ...            ...                              ...         ...                ...                                                ...   ...        ...               ...       ...
# 4403326           GR     Greece            NOx  NEC NFR14 sector classification      1B2aiv     NATIONAL TOTAL         Fugitive emissions oil: Refining / storage  2017        NaN  Gg (1000 tonnes)        ??
# 4406197           GR     Greece            SO2  NEC NFR14 sector classification      1B2aiv     NATIONAL TOTAL         Fugitive emissions oil: Refining / storage  2013        NaN  Gg (1000 tonnes)        ??
# 4414345           GR     Greece             Cu  NEC NFR14 sector classification  1A3aii(ii)                NaN                   Domestic aviation cruise (civil)  2012        NaN                 t        N.
# 4418311           GR     Greece            TSP  NEC NFR14 sector classification      1B2aiv     NATIONAL TOTAL         Fugitive emissions oil: Refining / storage  2021        NaN  Gg (1000 tonnes)        ??
# 4422069           LT  Lithuania            NH3  NEC NFR14 sector classification         3Df     NATIONAL TOTAL                      NATIONAL TOTAL FOR COMPLIANCE  2019        NaN  Gg (1000 tonnes)        ??
#
# [851 rows x 11 columns]

# %%
print("pollutants", *df_dict["pollutant_name"].index, sep=" | ")
print("sectors", *df_dict["sector_name"].index, sep=" | ")
# Out:
# pollutants | SO2 | NH3 | PM2.5 | NMVOC | NOx | Biomass | Other Fuels | PM10 | Pb | Cd | Cu | HCB | PCBs | Hg | Se | Benzo(b) Fluoranthene | Benzo(a) Pyrene | Solid Fuels | As | Ni | Indeno (1,2,3-cd) Pyrene | CO | Liquid Fuels | PCDD/PCDF (dioxins/furans) | Zn | Cr | Gaseous Fuels | TSP | Total PAHs | BC | benzo(k) Fluoranthene
# sectors | NATIONAL TOTAL FOR COMPLIANCE | Residential: Household and gardening (mobile) | Agriculture/Forestry/Fishing: Stationary | Carbide production | Fugitive emissions oil: Refining / storage | Open burning of waste | Titanium dioxide production | Manure management - Dairy cattle  | Off-farm storage, handling and transport of bulk agricultural products | Industrial wastewater handling | Cement production | Manure management - Sheep | Other mineral products | Food and beverages industry  | Railways | Nickel production | National navigation (shipping) | Wood processing | Other product use | Domestic solvent use including fungicides | Degreasing | Quarrying and mining of minerals other than coal | Crop residues applied to soils | International aviation LTO (civil) | Chemical industry: Other | Stationary combustion in manufacturing industries and construction: Non-metallic minerals | Other industrial processes | Construction and demolition | Other organic fertilisers applied to soils  (including compost) | Printing | International inland waterways | Manure management - Other animals | Lead production | Manure mangement -  Turkeys | Coating applications  | Ammonia production | Nitric acid production | Manure mangement -  Broilers | Use of pesticides | Domestic aviation LTO (civil) | Road transport: Heavy duty vehicles and buses | Stationary combustion in manufacturing industries and construction: Iron and steel | Biological treatment of waste - Solid waste disposal on land | Production of POPs | Other, Mobile (including military, land based and recreational boats) | Zinc production | Industrial waste incineration | Lime production | Municipal waste incineration | Cultivated crops | Stationary combustion in manufacturing industries and construction: Food processing, beverages and tobacco | Other waste incineration | Magnesium production | Aluminium production | Manure management - Horses | Urine and dung deposited by grazing animals  | Manure management - Swine   | Stationary combustion in manufacturing industries and construction: Pulp, Paper and Print | Stationary combustion in manufacturing industries and construction: Non-ferrous metals | Other natural emissions | Road transport: Light duty vehicles | Adipic acid production | Manure management - Non-dairy cattle  | Stationary combustion in manufacturing industries and construction: Chemicals | Glass production  | Animal manure applied to soils | Other production, consumption, storage, transportation or handling of bulk products | Agriculture other | Fugitive emissions oil: Exploration, production, transport | Other stationary (including military) | Fugitive emissions from natural gas (exploration, production, processing, transmission, storage, distribution and other) | Distribution of oil products | Domestic aviation cruise (civil) | Petroleum refining | Consumption of POPs and heavy metals  (e.g. electrical and scientific equipment) | Storage, handling and transport of metal products | Stationary combustion in manufacturing industries and construction: Other | Other fugitive emissions from solid fuels | Road transport: Automobile road abrasion | Volcanoes | Soda ash production | Other not included in national total of the entire territory | Iron and steel production | Indirect emissions from managed soils  | Asphalt roofing | Storage, handling and transport of chemical products | Public electricity and heat production | Mobile Combustion in manufacturing industries and construction | Pulp and paper industry | Manure mangement -  Laying hens | Domestic wastewater handling | Farm-level agricultural operations including storage, handling and transport of agricultural products | Road transport: Passenger cars | Other fugitive emissions from energy production  | Multilateral operations | Manure management - Mules and asses | Copper production | Pipeline transport  | Other (included in national total for entire territory) | Agriculture/Forestry/Fishing: Off-road vehicles and oth ...

# %%
pollutants_df = pd.DataFrame(columns=["unit"])
pollutants_df.index.name = "pollutant_name"
for poll in df_dict["pollutant_name"].index:
    val_count = df[df["pollutant_name"] == poll]["unit"].value_counts()
    if len(val_count) != 1:
        print(poll, val_count)
    pollutants_df.loc[poll] = val_count.index[0]
pollutants_df
# Out:
#                                         unit
# pollutant_name
# SO2                         Gg (1000 tonnes)
# NH3                         Gg (1000 tonnes)
# PM2.5                       Gg (1000 tonnes)
# NMVOC                       Gg (1000 tonnes)
# NOx                         Gg (1000 tonnes)
# Biomass                                TJNCV
# Other Fuels                            TJNCV
# PM10                        Gg (1000 tonnes)
# Pb                                         t
# Cd                                         t
# Cu                                         t
# HCB                                       kg
# PCBs                                      kg
# Hg                                         t
# Se                                         t
# Benzo(b) Fluoranthene                      t
# Benzo(a) Pyrene                            t
# Solid Fuels                            TJNCV
# As                                         t
# Ni                                         t
# Indeno (1,2,3-cd) Pyrene                   t
# CO                          Gg (1000 tonnes)
# Liquid Fuels                           TJNCV
# PCDD/PCDF (dioxins/furans)           g I-TEQ
# Zn                                         t
# Cr                                         t
# Gaseous Fuels                          TJNCV
# TSP                         Gg (1000 tonnes)
# Total PAHs                                 t
# BC                          Gg (1000 tonnes)
# benzo(k) Fluoranthene                      t

# %% [markdown]
# ## Plotting

# %%
pollutant = "PM2.5"
country = "France"
data = df[(df["pollutant_name"] == pollutant) & (df["country"] == country)]

top_avg = data.groupby("sector_name")["emissions"].mean().sort_values()
top_avg
# Out:
# sector_name
# Lead production                                      0.000005
# Nickel production                                    0.001451
# Manure management - Mules and asses                  0.001567
# Other industrial processes                           0.002228
# Manure management - Other animals                    0.004793
#                                                        ...
# Storage, handling and transport of metal products         NaN
# Urine and dung deposited by grazing animals               NaN
# Use of pesticides                                         NaN
# Volcanoes                                                 NaN
# Zinc production                                           NaN
# Name: emissions, Length: 136, dtype: float64

# %%
data.sort_values("year")
data.plot(kind="bar", x="Year", y=["emissions"], color="sector_name", title=f"{pollutant} emissions per sector in {country}")
# Out:
#         country_code country pollutant_name                      format_name sector_code parent_sector_code                                        sector_name  year  emissions              unit notations
# 2398614           FR  France          PM2.5  NEC NFR14 sector classification        3Da1     NATIONAL TOTAL  Inorganic N-fertilizers (includes also urea ap...  1980        NaN  Gg (1000 tonnes)        NR
# 3069188           FR  France          PM2.5  NEC NFR14 sector classification     1A3biii     NATIONAL TOTAL                      NATIONAL TOTAL FOR COMPLIANCE  1980        NaN  Gg (1000 tonnes)        NR
# 1576300           FR  France          PM2.5  NEC NFR14 sector classification       5C1bv     NATIONAL TOTAL                                          Cremation  1980        NaN  Gg (1000 tonnes)        NR
# 3075490           FR  France          PM2.5  NEC NFR14 sector classification         2A3     NATIONAL TOTAL                                  Glass production   1980        NaN  Gg (1000 tonnes)        NR
# 3076566           FR  France          PM2.5  NEC NFR14 sector classification      1B2aiv     NATIONAL TOTAL                      NATIONAL TOTAL FOR COMPLIANCE  1980        NaN  Gg (1000 tonnes)        NR
# ...              ...     ...            ...                              ...         ...                ...                                                ...   ...        ...               ...       ...
# 196960            FR  France          PM2.5  NEC NFR14 sector classification          2L     NATIONAL TOTAL  Other production, consumption, storage, transp...  2021        NaN  Gg (1000 tonnes)       NaN
# 1834867           FR  France          PM2.5  NEC NFR14 sector classification         3Dc     NATIONAL TOTAL  Farm-level agricultural operations including s...  2021   0.842860  Gg (1000 tonnes)       NaN
# 1820979           FR  France          PM2.5  NEC NFR14 sector classification        1A3c     NATIONAL TOTAL                                           Railways  2021   0.547254  Gg (1000 tonnes)       NaN
# 112123            FR  France          PM2.5  NEC NFR14 sector classification        3Da1     NATIONAL TOTAL  Inorganic N-fertilizers (includes also urea ap...  2021        NaN  Gg (1000 tonnes)        NE
# 2311488           FR  France          PM2.5  NEC NFR14 sector classification       2B10a     NATIONAL TOTAL                           Chemical industry: Other  2021   0.328731  Gg (1000 tonnes)       NaN
#
# [11070 rows x 11 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\lotod\Desktop\GIT\PFE-ESME-predict_cities_air_pollution\notebooks\1.0-rl-NEC-initial-exploration.ipynb Cell 17 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/lotod/Desktop/GIT/PFE-ESME-predict_cities_air_pollution/notebooks/1.0-rl-NEC-initial-exploration.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> data.sort_values("year")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lotod/Desktop/GIT/PFE-ESME-predict_cities_air_pollution/notebooks/1.0-rl-NEC-initial-exploration.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> data.plot(kind="bar", x="Year", y=["emissions"], color="sector_name", title=f"{pollutant} emissions per sector in {country}")
#
# File c:\Users\lotod\Desktop\GIT\PFE-ESME-predict_cities_air_pollution\.venv\Lib\site-packages\pandas\plotting\_core.py:961, in PlotAccessor.__call__(self, *args, **kwargs)
#     959 # when using another backend, get out of the way
#     960 if plot_backend.__name__ != "pandas.plotting._matplotlib":
# --> 961     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     963 if kind not in self._all_kinds:
#     964     raise ValueError(f"{kind} is not a valid plot kind")
#
# File c:\Users\lotod\Desktop\GIT\PFE-ESME-predict_cities_air_pollution\.venv\Lib\site-packages\plotly\__init__.py:108, in plot(data_frame, kind, **kwargs)
#     106     return area(data_frame, **new_kwargs)
#     107 if kind == "bar":
# --> 108     return bar(data_frame, **kwargs)
#     109 if kind == "barh":
#     110     return bar(data_frame, orientation="h", **kwargs)
#
# File c:\Users\lotod\Desktop\GIT\PFE-ESME-predict_cities_air_pollution\.venv\Lib\site-packages\plotly\express\_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     325 def bar(
#     326     data_frame=None,
#     327     x=None,
#    (...)
#     367     height=None,
#     368 ) -> go.Figure:
#     369     """
#     370     In a bar plot, each row of `data_frame` is represented as a rectangular
#     371     mark.
#     372     """
# --> 373     return make_figure(
#     374         args=locals(),
#     375         constructor=go.Bar,
#     376         trace_patch=dict(textposition="auto"),
#     377         layout_patch=dict(barmode=barmode),
#     378     )
#
# File c:\Users\lotod\Desktop\GIT\PFE-ESME-predict_cities_air_pollution\.venv\Lib\site-packages\plotly\express\_core.py:2076, in make_figure(args, constructor, trace_patch, layout_patch)
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File c:\Users\lotod\Desktop\GIT\PFE-ESME-predict_cities_air_pollution\.venv\Lib\site-packages\plotly\express\_core.py:1485, in build_dataframe(args, constructor)
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\lotod\Desktop\GIT\PFE-ESME-predict_cities_air_pollution\.venv\Lib\site-packages\plotly\express\_core.py:1210, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['country_code', 'country', 'pollutant_name', 'format_name', 'sector_code', 'parent_sector_code', 'sector_name', 'year', 'emissions', 'unit', 'notations'] but received: Year

# %%
# Out:
#         Country_Code      Country            Pollutant_name  \
# 1                 MT        Malta  Indeno (1,2,3-cd) Pyrene
# 3                 FR       France                     PM2.5
# 6                 NL  Netherlands                Total PAHs
# 12                LT    Lithuania                       NOx
# 17                DK      Denmark                     PM2.5
# ...              ...          ...                       ...
# 4430049           SE       Sweden                       NH3
# 4430052           FR       France                       SO2
# 4430058           HR      Croatia                       SO2
# 4430059           MT        Malta     Benzo(b) Fluoranthene
# 4430067           BG     Bulgaria           Benzo(a) Pyrene
#
#                              Format_name sector_code parent_sector_code  \
# 1        NEC NFR14 sector classification        1A5a     NATIONAL TOTAL
# 3        NEC NFR14 sector classification      1A4bii     NATIONAL TOTAL
# 6        NEC NFR14 sector classification          6A     NATIONAL TOTAL
# 12       NEC NFR14 sector classification        1A5a     NATIONAL TOTAL
# 17       NEC NFR14 sector classification        1A5c                NaN
# ...                                  ...         ...                ...
# 4430049  NEC NFR14 sector classification         11C                NaN
# 4430052  NEC NFR14 sector classification         2C4     NATIONAL TOTAL
# 4430058  NEC NFR14 sector classification        1A5b     NATIONAL TOTAL
# 4430059  NEC NFR14 sector classification        1A2a     NATIONAL TOTAL
# 4430067  NEC NFR14 sector classification         2B3     NATIONAL TOTAL
#
#                                                sector_name  Year  Emissions  \
# 1                    Other stationary (including military)  1997        NaN
# 3            Residential: Household and gardening (mobile)  1982        NaN
# 6        Other (included in national total for entire t...  2011        NaN
# 12                           NATIONAL TOTAL FOR COMPLIANCE  2003        NaN
# 17                                 Multilateral operations  1995        NaN
# ...                                                    ...   ...        ...
# 4430049                            Other natural emissions  2008        NaN
# 4430052                               Magnesium production  1999        NaN
# 4430058                      NATIONAL TOTAL FOR COMPLIANCE  2000        NaN
# 4430059  Stationary combustion in manufacturing industr...  2011        NaN
# 4430067                             Adipic acid production  2010        NaN
#
#                      Unit Notations
# 1                       t        NO
# 3        Gg (1000 tonnes)        NR
# 6                       t        NE
# 12       Gg (1000 tonnes)        NE
# 17       Gg (1000 tonnes)        NE
# ...                   ...       ...
# 4430049  Gg (1000 tonnes)        NO
# 4430052  Gg (1000 tonnes)        IE
# 4430058  Gg (1000 tonnes)        IE
# 4430059                 t        NO
# 4430067                 t        NO
#
# [1542219 rows x 11 columns]
